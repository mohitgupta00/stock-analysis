# %%
# !python test_multi_agent.py
# Out:
# 🚀 Starting Multi-Agent Stock Analysis System Test
#
# ...
# TESTING INDIVIDUAL AGENTS
# ...
#
# --- Fundamental Agent ---
# ✅ Score: 0.575
# 📊 Signal: HOLD
# 🎯 Confidence: 0.900
# 📝 Analysis: P/E: 22.278322, ROE: 29.0%, D/E: 8.437, Growth: 3.7%. Fair valuation. Strong profitability with good...
#
# --- Technical Agent ---
# ✅ Score: 0.600
# 📊 Signal: HOLD
# 🎯 Confidence: 0.900
# 📝 Analysis: RSI 62.1 in neutral zone. Strong uptrend with price above key moving averages. MACD indicating beari...
#
# --- Peer Comparison Agent ---
# ✅ Score: 0.733
# 📊 Signal: BUY
# 🎯 Confidence: 0.900
# 📝 Analysis: Trading at 15.5% discount to peer median P/E. ROE 19.3% above peer median - superior profitability. ...
#
# --- Macro Context Agent ---
# ✅ Score: 0.716
# 📊 Signal: BUY
# 🎯 Confidence: 0.800
# 📝 Analysis: Moderate GDP growth (6.2%) provides stable backdrop. Inflation within RBI comfort zone. Neutral mone...
#
# --- Risk Assessment Agent ---
# ✅ Score: 0.517
# 📊 Signal: WEAK_HOLD
# 🎯 Confidence: 0.900
# ...

# %%
# !python api/chat_interface.py
# Out:
# 🤖 Stock Analysis AI Assistant
# Ask me about any NSE stock! Type 'quit' to exit, 'help' for examples.
# ------------------------------------------------------------
#
# 💬 You: ^C
#
# 👋 Goodbye! Happy investing!

# %%
# !cat DA
